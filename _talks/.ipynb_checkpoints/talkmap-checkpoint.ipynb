# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
import glob
import getorg
from geopy import Nominatim
import folium
import time

# %%
g = glob.glob("*.md")

# %%
data_talks = []
for file in g:
    talk_dict = {}
    with open(file, 'r') as f:
        lines = f.read()
        
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]

            title_start = lines.find('title: "') + 8 #look for title
            title_trim = lines[title_start:]
            title_end = title_trim.find('"')
            title = title_trim[:title_end]
            
            venue_start = lines.find('venue: "') + 8 #look for venue
            venue_trim = lines[venue_start:]
            venue_end = venue_trim.find('"')
            venue_name = venue_trim[:venue_end]

            period_start = lines.find('date: ') + 6 #look for period
            period_trim = lines[period_start:]
            period_end = period_trim.find('\n')
            period = period_trim[:period_end]

            type_start = lines.find('type: "') + 7 #look for type
            type_trim = lines[type_start:]
            type_end = type_trim.find('\n')
            type = type_trim[:type_end -1]

            #get the name of the file
            link = "https://riccardogonzo.com/talks/" + file[:-3]

            talk_dict['title'] = title
            talk_dict['location'] = location
            talk_dict['venue'] = venue_name
            talk_dict['date'] = period
            talk_dict['type'] = type
            talk_dict['link'] = link
            
            data_talks.append(talk_dict)

# %%
geocoder = Nominatim(user_agent="riccardogonzo-talks-map")

from geopy.exc import GeocoderUnavailable, GeocoderTimedOut, GeocoderRateLimited

for talk in data_talks:
    if talk['location'] == "Online":
        talk['lat'] = None
        talk['lon'] = None
        continue
    print(talk['location'])
    try:
        location = geocoder.geocode(talk['location'], timeout=10)
        time.sleep(1.2)
        if location:
            talk['lat'] = location.latitude
            talk['lon'] = location.longitude
        else:
            talk['lat'] = None
            talk['lon'] = None
    except (GeocoderUnavailable, GeocoderTimedOut, GeocoderRateLimited) as e:
        print(f"Geocoding failed for {talk['location']}: {e}")
        talk['lat'] = None
        talk['lon'] = None
# Out:
# Reykjavík, Iceland
# Potsdam, Germany
# Taipei, Taiwan
# Rome, Italy
# Berlin, Germany
# Dublin, Ireland
# São Paulo, Brazil
# Seoul, South Korea
# Los Angeles, USA
# Cortona, Italy
# Edinburgh, UK
# Edinburgh, UK
# Zurich, Switzerland
# Göttingen, Germany
# Rome, Italy
# Paris, France
# Rome, Italy
# Plymouth, UK
# Edinburgh, UK
# Geneva, Switzerland
# Edinburgh, UK
# Brussels, Belgium
# Gif-sur-Yvette, France
# Southampton, UK
# Garching, Germany
# Copenhagen, Denmark
# Corfu, Greece
# Dublin, Ireland
# Geneva, Switzerland
# Santa Barbara, USA
# Moscow, Russia
# Pisa, Italy
# Birmingham, UK
# Padova, Italy
# Berlin, Germany
# Trieste, Italy
# Padova, Italy
# Nottingham, UK
# Plymouth, UK
# Southampton, UK
# Rome, Italy
# Rome, Italy
# Florence, Italy
# Edinburgh, UK
# Mainz, Germany
# Los Angeles, USA
# Berlin, Germany
# Copenhagen, Denmark
# Edinburgh, UK
# Zurich, Switzerland
# Florence, Italy
# Pasadena, USA
# Corfu, Greece

# %%
data_talks[32]
# Out:
# {'title': 'Worldline approach for Kerr black holes: PM vs GSF',
#  'location': 'Birmingham, UK',
#  'venue': 'Britgrav 2025',
#  'date': '2025-04-27',
#  'type': 'Contributed talk',
#  'link': 'https://riccardogonzo.com/talks/2025-04-27_britgrav',
#  'lat': 52.4796992,
#  'lon': -1.9026911}

# %%
data_talks[25]
# Out:
# {'title': 'The on-shell space of scattering and bound classical observables',
#  'location': 'Copenhagen, Denmark',
#  'venue': 'NBI',
#  'date': '2024-11-19',
#  'type': 'Invited seminar',
#  'link': 'https://riccardogonzo.com/talks/2024-11-19_nbi',
#  'lat': 55.6867243,
#  'lon': 12.5700724}

# %%
def convert_date(date):
    date = date.split('-')
    month = date[1]
    day = date[2]
    year = date[0]
    if month == '01':
        month = 'January'
    elif month == '02':
        month = 'February'
    elif month == '03':
        month = 'March'
    elif month == '04':
        month = 'April'
    elif month == '05':
        month = 'May'
    elif month == '06':
        month = 'June'
    elif month == '07':
        month = 'July'
    elif month == '08':
        month = 'August'
    elif month == '09':
        month = 'September'
    elif month == '10':
        month = 'October'
    elif month == '11':
        month = 'November'
    elif month == '12':
        month = 'December'
    
    if day.endswith('1') and day != '11':
        day += 'st'
    elif day.endswith('2') and day != '12':
        day += 'nd'
    elif day.endswith('3') and day != '13':
        day += 'rd'
    else:
        day += 'th'

    # if days starts with 0, remove it
    if day.startswith('0'):
        day = day[1:]
    
    return month + ' ' + day + ', ' + year

# %%
for talk in data_talks:
    talk['venue'] = talk['venue'].replace('CCS', 'Conference on Complex Systems')

# %%
# remove Online talks
data_talks = [talk for talk in data_talks if talk['location'] != 'Online']

# %%
# merge the talks that took place in the same location
talks_merged = []

unique_locations = list(set([talk['location'] for talk in data_talks]))

for location in unique_locations:
    location_talks = [talk for talk in data_talks if talk['location'] == location]
    if len(location_talks) == 1:
        talk = location_talks[0]
        text = '<p style="font-size:1.3em; font-family: Avenir"><b>' + talk['venue'] + "</b>, "
        text += talk["location"]+"<br /><i>" + talk['title']
        text += "</i><br />" + convert_date(talk['date']) + " (" + talk['type'].lower() + ")</p>"
        talks_merged.append({'text': text, 'lat': talk['lat'], 'lon': talk['lon'], 'type': talk['type'], 'type': location_talks[0]['type'], 'num': None})
    else:
        text = '<p style="font-size:1.3em; font-family: Avenir">'

        types = []
        # sort location talks by date
        location_talks = sorted(location_talks, key=lambda x: x['date'], reverse=True)
        for talk in location_talks:
            text += '<b>' + talk['venue'] + "</b>, "
            text += talk["location"]+"<br /><i>" + talk['title']
            text += "</i><br />" + convert_date(talk['date']) + " (" + talk['type'].lower() + ")<br /><br />"
            
            if talk['type'] not in types:
                types.append(talk['type'])
                
        # choose merged type with a clear priority + default
        merged_type = None
        if "Invited talk" in types:
            merged_type = "Invited talk"
        elif "Invited seminar" in types:
            merged_type = "Invited seminar"
        elif "Contributed talk" in types:
            merged_type = "Contributed talk"
        elif "Contributed poster" in types:
            merged_type = "Contributed poster"
    
        text += "</p>"
        talks_merged.append({'text': text, 'lat': location_talks[0]['lat'], 'lon': location_talks[0]['lon'], 'type': merged_type, 'num': len(location_talks)})

# %%
talks_merged
# Out:
# [{'text': '<p style="font-size:1.3em; font-family: Avenir"><b>University College Dublin</b>, Dublin, Ireland<br /><i>Classical amplitudes for the two-body problem in GR</i><br />March 21st, 2022 (invited seminar)<br /><br /><b>TCD</b>, Dublin, Ireland<br /><i>OPE at null infinity</i><br />January 30th, 2020 (invited seminar)<br /><br /></p>',
#   'lat': 53.3493795,
#   'lon': -6.2605593,
#   'type': 'Invited seminar',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>GGI workshop</b>, Florence, Italy<br /><i>Waveforms from the KMOC formalism and coherent states</i><br />May 17th, 2021 (invited talk)<br /><br /><b>XVI Avogadro Meeting</b>, Florence, Italy<br /><i>Light-ray operators and detector algebra</i><br />December 21st, 2020 (contributed talk)<br /><br /></p>',
#   'lat': 43.7697955,
#   'lon': 11.2556404,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Workshop on celestial amplitudes and flat space holography</b>, Corfu, Greece<br /><i>Celestial holography on non-trivial backgrounds</i><br />September 14th, 2022 (invited talk)<br /><br /><b>Celestial amplitudes and flat space holography workshop</b>, Corfu, Greece<br /><i>Leader of the discussion session \'Connections between gravity, classical observables\'</i><br />September 14th, 2022 (discussion session)<br /><br /></p>',
#   'lat': 39.591337,
#   'lon': 19.8596189,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>University of Nottingham</b>, Nottingham, UK<br /><i>Celestial holography on non-trivial backgrounds</i><br />November 18th, 2022 (invited seminar)</p>',
#   'lat': 52.9534236,
#   'lon': -1.1501168,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Worldline Seminars (online)</b>, Plymouth, UK<br /><i>Classical scattering and bound observables from the worldline approach to the two-body problem</i><br />September 17th, 2024 (invited seminar)<br /><br /><b>Physics in Intense Fields, PIF22</b>, Plymouth, UK<br /><i>High-energy limit of quantum and classical wave scattering observables</i><br />August 31st, 2022 (invited talk)<br /><br /></p>',
#   'lat': 50.3714122,
#   'lon': -4.1424451,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Amplitudes 2025</b>, Seoul, South Korea<br /><i>Dirac brackets for classical black hole scattering: from amplitudes to observables</i><br />June 17th, 2025 (invited talk)</p>',
#   'lat': 37.5666791,
#   'lon': 126.9782914,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>What is particle theory?</b>, Santa Barbara, USA<br /><i>Classical bound observables from the S-matrix formalism</i><br />January 16th, 2025 (invited talk)</p>',
#   'lat': 34.4221319,
#   'lon': -119.702667,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Harnack Haus</b>, Berlin, Germany<br /><i>What Particle Theory Teaches Us About Binary Black Holes</i><br />March 10th, 2026 (invited talk)<br /><br /><b>AEI</b>, Berlin, Germany<br /><i>Dirac brackets for classical black hole scattering</i><br />June 25th, 2025 (invited seminar)<br /><br /><b>DFG retreat, Humboldt University</b>, Berlin, Germany<br /><i>Shedding light on bound states with the S-matrix</i><br />September 19th, 2024 (invited seminar)<br /><br /></p>',
#   'lat': 52.5173885,
#   'lon': 13.3951309,
#   'type': 'Invited talk',
#   'num': 3},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Fundamental physics meets waveforms with LISA workshop</b>, Potsdam, Germany<br /><i>Black holes as point particles: from amplitudes to bound waveforms</i><br />September 6th, 2024 (invited talk)</p>',
#   'lat': 52.4009309,
#   'lon': 13.0591397,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Capra conference 2025</b>, Southampton, UK<br /><i>Worldline approach to Kerr black hole: PM vs. GSF</i><br />July 23rd, 2025 (contributed talk)<br /><br /><b>STAG centre</b>, Southampton, UK<br /><i>Spinning waveforms from classical amplitudes</i><br />November 10th, 2023 (invited seminar)<br /><br /></p>',
#   'lat': 50.9025349,
#   'lon': -1.404189,
#   'type': 'Invited seminar',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>CERN</b>, Geneva, Switzerland<br /><i>The ultra-relativistic limit of gravitational scattering</i><br />May 5th, 2026 (invited talk)<br /><br /><b>University of Geneva</b>, Geneva, Switzerland<br /><i>Shedding light on bound states with amplitudes</i><br />March 22nd, 2023 (invited seminar)<br /><br /></p>',
#   'lat': 46.2017559,
#   'lon': 6.1466014,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>EFT and Multi-Loop Methods for Advancing Precision in Collider and Gravitational</b>, Garching, Germany<br /><i>On-shell maps between scattering and bound observables</i><br />October 22nd, 2024 (invited talk)</p>',
#   'lat': 48.2513878,
#   'lon': 11.6509662,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>University of Göttingen</b>, Göttingen, Germany<br /><i>The structure of intertwiners in the infinite spin representation</i><br />May 29th, 2017 (invited seminar)</p>',
#   'lat': 51.5328328,
#   'lon': 9.9351811,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>NTNU (online)</b>, Taipei, Taiwan<br /><i>Gravitational bound waveforms from amplitudes</i><br />April 3rd, 2024 (invited seminar)</p>',
#   'lat': 25.0375198,
#   'lon': 121.5636796,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>ITMP (online)</b>, Moscow, Russia<br /><i>Gravitational bound waveforms from amplitudes</i><br />March 13th, 2024 (invited seminar)</p>',
#   'lat': 55.625578,
#   'lon': 37.6063916,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>IHES</b>, Gif-sur-Yvette, France<br /><i>Regge theory for gravity amplitudes</i><br />December 3rd, 2025 (invited seminar)</p>',
#   'lat': 48.7018823,
#   'lon': 2.134529,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Joint Belgian HEPTH Seminars</b>, Brussels, Belgium<br /><i>Gravitational bound waveforms from amplitudes</i><br />February 28th, 2024 (invited seminar)</p>',
#   'lat': 50.8467372,
#   'lon': 4.352493,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>First quantisation for physics in strong fields</b>, Edinburgh, UK<br /><i>Worldline approach for spinning bound binaries</i><br />February 26th, 2025 (invited talk)<br /><br /><b>Higgs Centre</b>, Edinburgh, UK<br /><i>Scattering and bound observables for spinning particles in Kerr</i><br />April 30th, 2024 (invited seminar)<br /><br /><b>Gravitational self-force and scattering amplitudes workshop</b>, Edinburgh, UK<br /><i>Leader of the discussion session \'Self-force and amplitudes\'</i><br />March 22nd, 2024 (discussion session)<br /><br /><b>General Relativity from AMPlitudes Alliance (GRAMPA), ICMS</b>, Edinburgh, UK<br /><i>Classical Gravitational Bound States with Amplitudes</i><br />January 23rd, 2024 (invited talk)<br /><br /><b>Higgs Centre</b>, Edinburgh, UK<br /><i>Bethe-Salpeter equation for classical bound states</i><br />December 1st, 2022 (invited seminar)<br /><br /><b>Higgs Centre</b>, Edinburgh, UK<br /><i>Coherent states from amplitudes and classical factorization</i><br />June 30th, 2021 (invited seminar)<br /><br /></p>',
#   'lat': 55.9533456,
#   'lon': -3.1883749,
#   'type': 'Invited talk',
#   'num': 6},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>IPhT</b>, Paris, France<br /><i>Boundary to bound dictionary for generic Kerr orbits</i><br />May 4th, 2023 (invited seminar)</p>',
#   'lat': 48.8534951,
#   'lon': 2.3483915,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Investigating Compact Objects and Binary Mergers with Gravitational Waves</b>, Rome, Italy<br /><i>Worldline approach for Kerr black holes: PM vs GSF</i><br />May 8th, 2025 (invited talk)<br /><br /><b>String Theory as a Bridge between Gauge Theory and Quantum Gravity</b>, Rome, Italy<br /><i>S-matrix tools for bound waveform modelling</i><br />February 18th, 2025 (invited talk)<br /><br /><b>Workshop JENAS Initiative: Gravitational Wave Probes of Fundamental Physics</b>, Rome, Italy<br /><i>Black holes as point particles: from amplitudes to self-force</i><br />February 13th, 2024 (invited talk)<br /><br /><b>Sapienza</b>, Rome, Italy<br /><i>Scattering and bound waveforms for Kerr black holes</i><br />November 22nd, 2023 (invited seminar)<br /><br /><b>Tor Vergata</b>, Rome, Italy<br /><i>Scattering and bound waveforms for Kerr black holes</i><br />November 20th, 2023 (invited seminar)<br /><br /></p>',
#   'lat': 41.8933203,
#   'lon': 12.4829321,
#   'type': 'Invited talk',
#   'num': 5},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>S-matrix bootstrap 2024 workshop</b>, Reykjavík, Iceland<br /><i>Leader of the discussion session \'Gravitational waves and scattering amplitudes\'</i><br />June 28th, 2024 (discussion session)</p>',
#   'lat': 64.145981,
#   'lon': -21.9422367,
#   'type': 'Discussion session',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Britgrav 2025</b>, Birmingham, UK<br /><i>Worldline approach for Kerr black holes: PM vs GSF</i><br />April 27th, 2025 (contributed talk)</p>',
#   'lat': 52.4796992,
#   'lon': -1.9026911,
#   'type': 'Contributed talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>New Frontiers in Theoretical Physics - XXXVII Convegno Nazionale di Fisica</b>, Cortona, Italy<br /><i>Classical Gravitational Bound States with Amplitudes</i><br />September 27th, 2023 (contributed talk)</p>',
#   'lat': 43.2752976,
#   'lon': 11.9850623,
#   'type': 'Contributed talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>IGAP</b>, Trieste, Italy<br /><i>Self-force EFT for black hole binaries: bridging weak and strong field via critical orbits</i><br />March 13th, 2026 (invited talk)</p>',
#   'lat': 45.6496485,
#   'lon': 13.7772781,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>GWs meet Amplitudes workshop</b>, São Paulo, Brazil<br /><i>From classical scattering amplitudes to bound state observables</i><br />August 22nd, 2023 (invited talk)</p>',
#   'lat': -23.5506507,
#   'lon': -46.6333824,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>SNS Pisa</b>, Pisa, Italy<br /><i>Classical bound observables from amplitudes</i><br />May 7th, 2024 (invited seminar)</p>',
#   'lat': 43.4714722,
#   'lon': 10.6797912,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Caltech</b>, Pasadena, USA<br /><i>Gravitational event shapes and coherent states for gravitational waves</i><br />September 29th, 2021 (invited seminar)</p>',
#   'lat': 34.1476507,
#   'lon': -118.144155,
#   'type': 'Invited seminar',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>ECCF 2024 workshop</b>, Mainz, Germany<br /><i>\'Light-ray operators in gauge and gravity theory: new infrared finite local observables</i><br />July 16th, 2024 (invited talk)</p>',
#   'lat': 49.9995205,
#   'lon': 8.2736253,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Amplitude Lounge Seminar series (online)</b>, Padova, Italy<br /><i>High-energy gravitational scattering: Regge theory and shock wave formalism</i><br />November 7th, 2025 (invited seminar)<br /><br /><b>University of Padova</b>, Padova, Italy<br /><i>Amplitudes for the classical two-body problem in general relativity</i><br />April 28th, 2022 (invited seminar)<br /><br /></p>',
#   'lat': 45.391408,
#   'lon': 11.8058487,
#   'type': 'Invited seminar',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>UCLA</b>, Los Angeles, USA<br /><i>Insights into the scattering-to-bound map from the self-force approach</i><br />February 7th, 2025 (invited seminar)<br /><br /><b>QCD meets gravity</b>, Los Angeles, USA<br /><i>An infinity of amplitude relations in classical physics</i><br />December 15th, 2021 (invited talk)<br /><br /></p>',
#   'lat': 34.0536909,
#   'lon': -118.242766,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>NBI</b>, Copenhagen, Denmark<br /><i>The on-shell space of scattering and bound classical observables</i><br />November 19th, 2024 (invited seminar)<br /><br /><b>NBI Institute</b>, Copenhagen, Denmark<br /><i>Waveforms from amplitudes and coherent states</i><br />February 18th, 2021 (invited seminar)<br /><br /></p>',
#   'lat': 55.6867243,
#   'lon': 12.5700724,
#   'type': 'Invited seminar',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Zurich</b>, Zurich, Switzerland<br /><i>From amplitudes to gravitational bound observables</i><br />May 17th, 2024 (invited seminar)<br /><br /><b>QCD meets gravity</b>, Zurich, Switzerland<br /><i>Bethe-Salpeter equation for classical gravitational bound states</i><br />December 14th, 2022 (invited talk)<br /><br /></p>',
#   'lat': 47.3744489,
#   'lon': 8.5410422,
#   'type': 'Invited talk',
#   'num': 2}]

# %%
n = folium.Map(location=[40,40], tiles="cartodb positron", zoom_start=3, z_index = 0)

folium.map.CustomPane("Invited talk", z_index=1000).add_to(n)
folium.map.CustomPane("Contributed talk", z_index=999).add_to(n)
folium.map.CustomPane("Contributed poster", z_index=998).add_to(n)

folium.map.CustomPane("arrow", z_index=450).add_to(n)
# sort data talks in such a way that posters are at the beginning, contributed talks in the middle, and invited talks at the end

talks_merged = sorted(talks_merged, key=lambda x: x['type'])

for idx, talk in enumerate(talks_merged):
    # iframe = folium.IFrame('<p style="font-family: Avenir"><b>' + talk['venue'] + "</b>, "+talk["location"]+"<br /><i>" + talk['title'] + "</i><br />" + convert_date(talk['date']) + " (" +
    #                        talk['type'].lower() + ")</p>", width=500, height=150)
    #html = '<p style="font-size:1.3em; font-family: Avenir"><b>' + talk['venue'] + "</b>, "+ talk["location"]+"<br /><i>" + talk['title'] + "</i><br />" + convert_date(talk['date']) + " (" + talk['type'].lower() + ")</p>"
    
    popup = folium.Popup(talk['text'], min_width=200, max_width=300, max_height=150, min_height=100)

    # set a default
    color = "gray"

    if talk['type'] == 'Invited talk':
        color = 'darkred'

    elif talk['type'] == 'Invited seminar':
        color = 'blue'

    elif talk['type'] == 'Contributed talk':
        color = 'darkblue'

    folium.Marker(location = [talk['lat'], talk['lon']], popup=popup, marker_size = 100,
                  icon=folium.Icon(color=color, prefix = "fa")).add_to(n)

n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42b898afbdaac5643e5f8fa50277ebcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42b898afbdaac5643e5f8fa50277ebcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42b898afbdaac5643e5f8fa50277ebcb = L.map(
#                 &quot;map_42b898afbdaac5643e5f8fa50277ebcb&quot;,
#                 {
#                     center: [40.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;zIndex&quot;: 0,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c0435125b55de4d85e2adf88414e0fc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4c0435125b55de4d85e2adf88414e0fc.addTo(map_42b898afbdaac5643e5f8fa50277ebcb);
#
#
#             var pane_d7c51a867bba16aa8cb0f23b4c02db60 = map_42b898afbdaac5643e5f8fa50277ebcb.createPane(
#                 &quot;Invited talk&quot;);
#             pane_d7c51a867bba16aa8cb0f23b4c02db60.style.zIndex = 1000;
#
#                 pane_d7c51a867bba16aa8cb0f23b4c02db60.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var pane_496162a54a5768bee06617529a748d8e = map_42b898afbdaac5643e5f8fa50277ebcb.createPane(
#                 &quot;Contributed talk&quot;);
#             pane_496162a54a5768bee06617529a748d8e.style.zIndex = 999;
#
#                 pane_496162a54a5768bee06617529a748d8e.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var pane_b3e279f1bfa368986315f6d1253583f2 = map_42b898afbdaac5643e5f8fa50277ebcb.createPane(
#                 &quot;Contributed poster&quot;);
#             pane_b3e279f1bfa368986315f6d1253583f2.style.zIndex = 998;
#
#                 pane_b3e279f1bfa368986315f6d1253583f2.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var pane_0b9c6e5562a8d0992bcb083e6c06362f = map_42b898afbdaac5643e5f8fa50277ebcb.createPane(
#                 &quot;arrow&quot;);
#             pane_0b9c6e5562a8d0992bcb083e6c06362f.style.zIndex = 450;
#
#                 pane_0b9c6e5562a8d0992bcb083e6c06362f.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var marker_ee1afffcb6c58344285b2b790f0d7dd3 = L.marker(
#                 [52.4796992, -1.9026911],
#                 {
#   &quot;markerSize&quot;: 100,
# }
#             ).addTo(map_42b898afbdaac5643e5f8fa50277ebcb);
#
#
#             var icon_f47ab632f9fd77756196d4504e7a8584 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_594b48205c96635cea85ccd04040bd3e = L.popup({
#   &quot;maxWidth&quot;: 300,
#   &quot;minWidth&quot;: 200,
#   &quot;maxHeight&quot;: 150,
#   &quot;minHeight&quot;: 100,
# });
#
#
#
#                 var html_cfef9dc30074e8640de3599c183b2089 = $(`&lt;div id=&quot;html_cfef9dc30074e8640de3599c183b2089&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;p style=&quot;font-size:1.3em; font-family: Avenir&quot;&gt;&lt;b&gt;Britgrav 2025&lt;/b&gt;, Birmingham, UK&lt;br /&gt;&lt;i&gt;Worldline approach for Kerr black holes: PM vs GSF&lt;/i&gt;&lt;br /&gt;April 27th, 2025 (contributed talk)&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_594b48205c96635cea85ccd04040bd3e.setContent(html_cfef9dc30074e8640de3599c183b2089);
#
#
#
#         marker_ee1afffcb6c58344285b2b790f0d7dd3.bindPopup(popup_594b48205c96635cea85ccd04040bd3e)
#         ;
#
#
#
#
#                 marker_ee1afffcb6c58344285b2b790f0d7dd3.setIcon(icon_f47ab632f9fd77756196d4504e7a8584);
#
#
#             var marker_9befbc1506d2190ac29cc03c4884c287 = L.marker(
#                 [43.2752976, 11.9850623],
#                 {
#   &quot;markerSize&quot;: 100,
# }
#             ).addTo(map_42b898afbdaac5643e5f8fa50277ebcb);
#
#
#             var icon_96a97de999886cc812d0efb40f4b4a9f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9cac8ac8693fc2974988654e1330affd = L.popup({
#   &quot;maxWidth&quot;: 300,
#   &quot;minWidth&quot;: 200,
#   &quot;m

# %%
# get the minimum and maximum latitude and longitude
min_lat = min([talk['lat'] for talk in data_talks if talk['lat'] is not None])
max_lat = max([talk['lat'] for talk in data_talks if talk['lat'] is not None])

min_lon = min([talk['lon'] for talk in data_talks if talk['lon'] is not None])
max_lon = max([talk['lon'] for talk in data_talks if talk['lon'] is not None])

n.fit_bounds([[min_lat, min_lon], [max_lat, max_lon]])

# %%
# save the map in html

n.save('../talkmap/talks_map.html')
